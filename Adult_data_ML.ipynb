# %%
import pandas as pd

# %%
import numpy as np

# %%
dt = pd.read_csv(r"C:\Users\BIT\Downloads\adult\adult.data",header=None,skipinitialspace=True)

# %%
dt
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
dt.head(5)
# Out:
#    0                 1       2          3   4                   5   \
# 0  39         State-gov   77516  Bachelors  13       Never-married
# 1  50  Self-emp-not-inc   83311  Bachelors  13  Married-civ-spouse
# 2  38           Private  215646    HS-grad   9            Divorced
# 3  53           Private  234721       11th   7  Married-civ-spouse
# 4  28           Private  338409  Bachelors  13  Married-civ-spouse
#
#                   6              7      8       9     10  11  12  \
# 0       Adm-clerical  Not-in-family  White    Male  2174   0  40
# 1    Exec-managerial        Husband  White    Male     0   0  13
# 2  Handlers-cleaners  Not-in-family  White    Male     0   0  40
# 3  Handlers-cleaners        Husband  Black    Male     0   0  40
# 4     Prof-specialty           Wife  Black  Female     0   0  40
#
#               13     14
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# 4           Cuba  <=50K

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32561 non-null  int64
#  1   1       32561 non-null  object
#  2   2       32561 non-null  int64
#  3   3       32561 non-null  object
#  4   4       32561 non-null  int64
#  5   5       32561 non-null  object
#  6   6       32561 non-null  object
#  7   7       32561 non-null  object
#  8   8       32561 non-null  object
#  9   9       32561 non-null  object
#  10  10      32561 non-null  int64
#  11  11      32561 non-null  int64
#  12  12      32561 non-null  int64
#  13  13      32561 non-null  object
#  14  14      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dt.columns = ['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week',
                'native_country','income']

# %%
dt.head(10)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
dt.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
#checking missing values...
dt.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
for i in dt.columns:
    print(i,':',sum((dt[i])=='?'))
# Out:
# age : 0
# workclass : 1836
# fnlwgt : 0
# education : 0
# education_num : 0
# marital_status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per_week : 0
# native_country : 583
# income : 0

# %%
for i  in dt.columns:
    print(i,':','\n',dt[i].unique())
# Out:
# age :
#  [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# workclass :
#  ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# fnlwgt :
#  [ 77516  83311 215646 ...  34066  84661 257302]
# education :
#  ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# education_num :
#  [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# marital_status :
#  ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# occupation :
#  ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
# ...

# %%
for i in dt.columns:
    print(i,':',sum((dt[i])=='?'))
# Out:
# age : 0
# workclass : 1836
# fnlwgt : 0
# education : 0
# education_num : 0
# marital_status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per_week : 0
# native_country : 583
# income : 0

# %%
df=dt.describe(include='all')

# %%
df
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital_status      occupation relationship   race    sex  \
# ...

# %%
df.dtypes
# Out:
# age               float64
# workclass          object
# fnlwgt            float64
# education          object
# education_num     float64
# marital_status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital_gain      float64
# capital_loss      float64
# hours_per_week    float64
# native_country     object
# income             object
# dtype: object

# %%
for i in ['workclass','occupation','native_country']:
    dt.replace('?',df[i][2],inplace=True)
# Out:
# C:\Users\BIT\AppData\Local\Temp\ipykernel_6224\1403532709.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dt.replace('?',df[i][2],inplace=True)

# %%
for i in dt.columns:
    print(i,':',sum((dt[i])=='?'))
# Out:
# age : 0
# workclass : 0
# fnlwgt : 0
# education : 0
# education_num : 0
# marital_status : 0
# occupation : 0
# relationship : 0
# race : 0
# sex : 0
# capital_gain : 0
# capital_loss : 0
# hours_per_week : 0
# native_country : 0
# income : 0

# %%
# data Analysis
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(x=dt['age'][dt['income']=='<=50K'])
sns.displot(x=dt['age'][dt['income']=='>50K'])
plt.show()

# %%
#hist plot
sns.histplot(x=dt['age'][dt['income']=='<=50K'])
sns.histplot(x=dt['age'][dt['income']=='>50K'])
plt.show()

# %%
#barplot
sns.kdeplot(x=dt['age'][dt['income']=='<=50K'])
sns.kdeplot(x=dt['age'][dt['income']=='>50K'])
plt.show()

# %%
dt.head(5)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
sns.kdeplot(x=dt['age'][dt['sex']=='Male'])
sns.kdeplot(x=dt['age'][dt['sex']=='Female'])
plt.show()

# %%
# sns.pairplot(dt,hue="income")
# plt.show()

# %%
sns.histplot(x=dt['fnlwgt'][dt['race']=='White'])
sns.histplot(x=dt['fnlwgt'][dt['race']=='black'])
plt.show()

# %%
sns.boxplot(x=dt['fnlwgt'][dt['race']=='White'])
sns.boxplot(x=dt['fnlwgt'][dt['race']=='black'])
plt.show()

# %%
sns.violinplot(x=dt['fnlwgt'][dt['race']=='White'])
sns.violinplot(x=dt['fnlwgt'][dt['race']=='black'])
plt.show()

# %%
# Encoding

# %%
dt.head(5)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le9=LabelEncoder()
dt.workclass=le9.fit_transform(dt.workclass)

# %%
le1=LabelEncoder()
dt.education=le1.fit_transform(dt.education)

# %%
le2=LabelEncoder()
dt.marital_status=le2.fit_transform(dt.marital_status)

# %%
le3=LabelEncoder()
dt.occupation=le3.fit_transform(dt.occupation)

# %%
le4=LabelEncoder()
dt.relationship=le4.fit_transform(dt.relationship)

# %%
le5=LabelEncoder()
dt.race=le5.fit_transform(dt.race)

# %%
le6=LabelEncoder()
dt.sex=le6.fit_transform(dt.sex)

# %%
le7=LabelEncoder()
dt.native_country=le7.fit_transform(dt.native_country)

# %%
le8=LabelEncoder()
dt.income=le8.fit_transform(dt.income)

# %%
dt.head(5)
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          6   77516          9             13               4
# 1   50          5   83311          9             13               2
# 2   38          3  215646         11              9               0
# 3   53          3  234721          1              7               2
# 4   28          3  338409          9             13               2
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           0             1     4    1          2174             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40              39       0
# 1              13              39       0
# ...

# %%
dt['workclass'].unique()
# Out:
# array([6, 5, 3, 0, 1, 4, 7, 2])

# %%
le9.inverse_transform([6, 5, 3, 0, 1, 4, 7, 2])
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
dt['income'].unique()
# Out:
# array([0, 1])

# %%
le8.inverse_transform([0, 1])
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
dt['native_country'].unique()
# Out:
# array([39,  4, 22, 18, 32, 25, 35, 33, 15,  8,  1, 10, 19, 29, 21, 30,  3,
#         0, 37,  6, 24, 36, 13, 31,  5,  7,  9, 12,  2, 23, 41, 28, 27, 34,
#        38, 11, 26, 40, 16, 20, 17, 14])

# %%
le7.inverse_transform([39,  4, 22, 18, 32, 25, 35, 33, 15,  8,  1, 10, 19, 29, 21, 30,  3,
        0, 37,  6, 24, 36, 13, 31,  5,  7,  9, 12,  2, 23, 41, 28, 27, 34,
       38, 11, 26, 40, 16, 20, 17, 14])
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', 'Private', 'Mexico',
#        'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany',
#        'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
dt['sex'].unique()
# Out:
# array([1, 0])

# %%
le6.inverse_transform([1, 0])
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dt['race'].unique()
# Out:
# array([4, 2, 1, 0, 3])

# %%
le5.inverse_transform([4, 2, 1, 0, 3])
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
dt['relationship'].unique()
# Out:
# array([1, 0, 5, 3, 4, 2])

# %%
le4.inverse_transform([1, 0, 5, 3, 4, 2])
# Out:
# array(['Not-in-family', 'Husband', 'Wife', 'Own-child', 'Unmarried',
#        'Other-relative'], dtype=object)

# %%
dt['occupation'].unique()
# Out:
# array([ 0,  3,  5, 10,  7, 12,  2, 14,  4,  6, 13,  9, 11,  1,  8])

# %%
le3.inverse_transform([ 0,  3,  5, 10,  7, 12,  2, 14,  4,  6, 13,  9, 11,  1,  8])
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', 'Private', 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)

# %%
dt['marital_status'].unique()
# Out:
# array([4, 2, 0, 3, 5, 1, 6])

# %%
le2.inverse_transform([4, 2, 0, 3, 5, 1, 6])
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Divorced',
#        'Married-spouse-absent', 'Separated', 'Married-AF-spouse',
#        'Widowed'], dtype=object)

# %%
dt['education'].unique()
# Out:
# array([ 9, 11,  1, 12,  6, 15,  7,  8,  5, 10, 14,  4,  0,  3, 13,  2])

# %%
le1.inverse_transform([ 9, 11,  1, 12,  6, 15,  7,  8,  5, 10, 14,  4,  0,  3, 13,  2])
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
plt.figure(figsize=(20,15))
c= dt.corr()
sns.heatmap(c,annot=True)
plt.show()

# %%
# input out creation

# %%
ip=dt.drop('income',axis=1)
op = dt.income

# %% [markdown]
# train testsplit

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(ip,op,train_size=0.8)

# %% [markdown]
# standard scalar

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train= sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
# machine learning model : logistic regression 
it simple trying to convert the independent variable to a expression of probability with the range of0s and 1s with respect to the dependent variable.
sigmoid function :
# Out:
#   Cell In[57], line 2
#     it simple trying to convert the independent variable to a expression of probability with the range of0s and 1s with respect to the dependent variable.
#                                                                                                                 ^
# SyntaxError: invalid decimal literal

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Prediction

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(6513,))

# %% [markdown]
# Accuracy

# %% [markdown]
# confusion matrics

# %% [markdown]
# a confusion matrics is a table used to evaluate the performance of a classifaction model it shows you how well your model predicted the actual classes by comparing :
# - what the mmodel predicted
# - what the actual correct answer were.

# %% [markdown]
# Accuracy tells u how many total prediction wait correct
# - formulaa:   correct prediction / total prediction
#        TN +TP/TN+FP+FN+TP

# %% [markdown]
# f1-score :
# -it is the harmonic mean of precision and recall
# -2*(recll*precision/ recall + precision)

# %% [markdown]
# -good when u need a balanced between precision and recall .
# -it balanced both FP and FN

# %% [markdown]
# Precision:- it tells u how many predictive positives were  actually correct .   prediction Actual Positive/total predicted positive

# %% [markdown]
# recall:- it tells u how many actual positive were correctly found.
#     - prediction Actual positive/total actual positive

# %% [markdown]
# #accuracy....
# Accuracy : overallcorectness
# precision : correction of positives
# recall: how many actuall positive are cought
# f1_score :balancee between precision and recall.

# %%
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score
acc = accuracy_score(pred,y_test)
recall = recall_score(pred,y_test)
f1 = f1_score(pred,y_test)
precision= precision_score(pred,y_test)
print(f'Accuracy score :{acc}')
print(f'Recall score :{recall}')
print(f'f1 score :{f1}')
print(f'Precision score :{precision}')
# Out:
# Accuracy score :0.8226623675725472
# Recall score :0.6944990176817288
# f1 score :0.5504087193460491
# Precision score :0.4558349451966473

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(pred,y_test)
cm
# Out:
# array([[4651,  844],
#        [ 311,  707]])

# %%
cmd = ConfusionMatrixDisplay(cm)

# %%
cmd.plot()

# %% [markdown]
# dt-25-10-25

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(6513,))

# %%
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score
acc = accuracy_score(pred,y_test)
recall = recall_score(pred,y_test)
f1 = f1_score(pred,y_test)
precision= precision_score(pred,y_test)
print(f'Accuracy score :{acc}')
print(f'Recall score :{recall}')
print(f'f1 score :{f1}')
print(f'Precision score :{precision}')
# Out:
# Accuracy score :0.8226623675725472
# Recall score :0.6944990176817288
# f1 score :0.5504087193460491
# Precision score :0.4558349451966473

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(pred,y_test)
cm
# Out:
# array([[4651,  844],
#        [ 311,  707]])

# %%
cmd = ConfusionMatrixDisplay(cm)

# %%
cmd.plot()

# %%
from sklearn.svm import SVC
svm=SVC(kernel='rbf',C=1000,gamma=0.01)
svm.fit(x_train,y_train)
# Out:
# SVC(C=1000, gamma=0.01)

# %%
pred3 = svm.predict(x_test)
pred3
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(6513,))

# %%
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score
acc = accuracy_score(pred3,y_test)
recall = recall_score(pred3,y_test)
f1 = f1_score(pred,y_test)
precision= precision_score(pred3,y_test)
print(f'Accuracy score :{acc}')
print(f'Recall score :{recall}')
print(f'f1 score :{f1}')
print(f'Precision score :{precision}')
# Out:
# Accuracy score :0.8440042990941194
# Recall score :0.7246011754827876
# f1 score :0.5504087193460491
# Precision score :0.556415215989684

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(pred3,y_test)
cm
# Out:
# array([[4634,  688],
#        [ 328,  863]])

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()
